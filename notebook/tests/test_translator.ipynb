# %%
import pandas as pd
import numpy as np
import os
import re

BASE_DIR = os.getcwd()
DIR_NAME = os.path.basename(BASE_DIR)
print(BASE_DIR, DIR_NAME)
while DIR_NAME != "RakutenTeam": 
    BASE_DIR = os.path.realpath(os.path.join(os.path.dirname(__name__), '..'))
    DIR_NAME = os.path.basename(BASE_DIR)
    os.chdir(BASE_DIR)
    DATA_DIR = os.path.join(BASE_DIR, 'data')
    print( BASE_DIR, DATA_DIR, DIR_NAME)
# Out:
# c:\Users\mangg\projects\RakutenTeam\notebook\tests tests
# C:\Users\mangg\projects\RakutenTeam\notebook C:\Users\mangg\projects\RakutenTeam\notebook\data notebook
# C:\Users\mangg\projects\RakutenTeam C:\Users\mangg\projects\RakutenTeam\data RakutenTeam

# %%
from src.data_loader import import_data

folder_path = os.path.join(DATA_DIR, "clean")
print(folder_path)
# Out:
# C:\Users\mangg\projects\RakutenTeam\data\clean

# %%
df = import_data(folder_path=folder_path)
df = df.drop(columns=["designation_translated", "description_translated"])

# %%
df.head()
# Out:
#    prdtypecode                                        designation  \
# 0           10  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1         2280  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2           50  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3         1280  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4         2705                               La Guerre Des Tuques
#
#                                          description   productid     imageid  \
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des idées de grandeur. Il veut organiser...   278535884  1077757786
#
#   language
# 0       de
# 1       fr
# 2       fr
# 3       en
# 4       fr

# %%
from src.features.text.transformers.translators import TextTranslator

translator = TextTranslator(
    text_column="designation",
    lang_column="language"
)

print(translator.lang_column, translator.text_column, translator.target_lang)

translations = translator.fit_transform(df)
# Out:
# Neither PyTorch nor TensorFlow >= 2.0 have been found.Models won't be available and only tokenizers, configurationand file/data utilities can be used.
# language designation fr
# 0        Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1        Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2        Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3        Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                                     La Guerre Des Tuques
#                                ...
# 84911                          The Sims [ Import Anglais ]
# 84912    Kit piscine acier NEVADA déco pierre Ø 3.50m x...
# 84913    Journal Officiel De La Republique Francaise N°...
# 84914    Table Basse Bois De Récupération Massif Base B...
# 84915    Gomme De Collection 2 Gommes Pinguin Glace Ver...
# Name: translation, Length: 84916, dtype: object
# 13656
# Traduction de 0 à 100 complète
# Traduction de 100 à 200 complète
# Traduction de 200 à 300 complète
# Traduction de 300 à 400 complète
# Traduction de 400 à 500 complète
# Traduction de 500 à 600 complète
# Traduction de 600 à 700 complète
# Traduction de 700 à 800 complète
# Traduction de 800 à 900 complète
# Traduction de 900 à 1000 complète
# Traduction de 1000 à 1100 complète
# Traduction de 1100 à 1200 complète
# Traduction de 1200 à 1300 complète
# Traduction de 1300 à 1400 complète
# Traduction de 1400 à 1500 complète
# Traduction de 1500 à 1600 complète
# Traduction de 1600 à 1700 complète
# Traduction de 1700 à 1800 complète
# Traduction de 1800 à 1900 complète
# Traduction de 1900 à 2000 complète
# Traduction de 2000 à 2100 complète
# Traduction de 2100 à 2200 complète
# Traduction de 2200 à 2300 complète
# Traduction de 2300 à 2400 complète
# Traduction de 2400 à 2500 complète
# Traduction de 2500 à 2600 complète
# Traduction de 2600 à 2700 complète
# Traduction de 2700 à 2800 complète
# Traduction de 2800 à 2900 complète
# Traduction de 2900 à 3000 complète
# Traduction de 3000 à 3100 complète
# Traduction de 3100 à 3200 complète
# Traduction de 3200 à 3300 complète
# Traduction de 3300 à 3400 complète
# Traduction de 3400 à 3500 complète
# Traduction de 3500 à 3600 complète
# Traduction de 3600 à 3700 complète
# Traduction de 3700 à 3800 complète
# Traduction de 3800 à 3900 complète
# Traduction de 3900 à 4000 complète
# Traduction de 4000 à 4100 complète
# Traduction de 4100 à 4200 complète
# Traduction de 4200 à 4300 complète
# Traduction de 4300 à 4400 complète
# Traduction de 4400 à 4500 complète
# Traduction de 4500 à 4600 complète
# Traduction de 4600 à 4700 complète
# Traduction de 4700 à 4800 complète
# Traduction de 4800 à 4900 complète
# Traduction de 4900 à 5000 complète
# Traduction de 5000 à 5100 complète
# Traduction de 5100 à 5200 complète
# Traduction de 5200 à 5300 complète
# Traduction de 5300 à 5400 complète
# Traduction de 5400 à 5500 complète
# Traduction de 5500 à 5600 complète
# Traduction de 5600 à 5700 complète
# Traduction de 5700 à 5800 complète
# Traduction de 5800 à 5900 complète
# Traduction de 5900 à 6000 complète
# Traduction de 6000 à 6100 complète
# Traduction de 6100 à 6200 complète
# Traduction de 6200 à 6300 complète
# Traduction de 6300 à 6400 complète
# Traduction de 6400 à 6500 complète
# Traduction de 6500 à 6600 complète
# Traduction de 6600 à 6700 complète
# Traduction de 6700 à 6800 complète
# Traduction de 6800 à 6900 complète
# Traduction de 6900 à 7000 complète
# Traduction de 7000 à 7100 complète
# Traduction de 7100 à 7200 complète
# Traduction de 7200 à 7300 complète
# Traduction de 7300 à 7400 complète
# Traduction de 7400 à 7500 complète
# Traduction de 7500 à 7600 complète
# Traduction de 7600 à 7700 complète
# Traduction de 7700 à 7800 complète
# Traduction de 7800 à 7900 complète
# Traduction de 7900 à 8000 complète
# Traduction de 8000 à 8100 complète
# Traduction de 8100 à 8200 complète
# Traduction de 8200 à 8300 complète
# Traduction de 8300 à 8400 complète
# Traduction de 8400 à 8500 complète
# Traduction de 8500 à 8600 complète
# Traduction de 8600 à 8700 complète
# Traduction de 8700 à 8800 complète
# Traduction de 8800 à 8900 complète
# Traduction de 8900 à 9000 complète
# Traduction de 9000 à 9100 complète
# Traduction de 9100 à 9200 complète
# Traduction de 9200 à 9300 complète
# Traduction de 9300 à 9400 complète
# Traduction de 9400 à 9500 complète
# Traduction de 9500 à 9600 complète
# Traduction de 9600 à 9700 complète
# Traduction de 9700 à 9800 complète
# Traduction de 9800 à 9900 complète
# Traduction de 9900 à 10000 complète
# Traduction de 10000 à 10100 complète
# Traduction de 10100 à 10200 complète
# Traduction de 10200 à 10300 complète
# Traduction de 10300 à 10400 complète
# Traduction de 10400 à 10500 complète
# Traduction de 10500 à 10600 complète
# Traduction de 10600 à 10700 complète
# Traduction de 10700 à 10800 complète
# Traduction de 10800 à 10900 complète
# Traduction de 10900 à 11000 complète
# Traduction de 11000 à 11100 complète
# Traduction de 11100 à 11200 complète
# Traduction de 11200 à 11300 complète
# Traduction de 11300 à 11400 complète
# Traduction de 11400 à 11500 complète
# Traduction de 11500 à 11600 complète
# Traduction de 11600 à 11700 complète
# Traduction de 11700 à 11800 complète
# Traduction de 11800 à 11900 complète
# Traduction de 11900 à 12000 complète
# Traduction de 12000 à 12100 complète
# Traduction de 12100 à 12200 complète
# Traduction de 12200 à 12300 complète
# Traduction de 12300 à 12400 complète
# Traduction de 12400 à 12500 complète
# Traduction de 12500 à 12600 complète
# Traduction de 12600 à 12700 complète
# Traduction de 12700 à 12800 complète
# Traduction de 12800 à 12900 complète
# Traduction de 12900 à 13000 complète
# Traduction de 13000 à 13100 complète
# Traduction de 13100 à 13200 complète
# Traduction de 13200 à 13300 complète
# Traduction de 13300 à 13400 complète
# Traduction de 13400 à 13500 complète
# Traduction de 13500 à 13600 complète
# Traduction de 13600 à 13656 complète

# %%
translations
# Out:
# 0        Olivia: Personalized notebook / 150 pages / do...
# 1        Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2        Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3        Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                                     La Guerre Des Tuques
#                                ...
# 84911                          The Sims [ Import Anglais ]
# 84912    Kit piscine acier NEVADA déco pierre Ø 3.50m x...
# 84913    Journal Officiel De La Republique Francaise N°...
# 84914    Table Basse Bois De Récupération Massif Base B...
# 84915    Gomme De Collection 2 Gommes Pinguin Glace Ver...
# Name: translation, Length: 84916, dtype: object

# %%
#from src.features.Rakuten_preprocessing import Rakuten_txt_translate

# %%
#translations2
